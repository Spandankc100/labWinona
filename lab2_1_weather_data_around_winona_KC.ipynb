# %% [markdown]
# # EXAM - Weather Data Around Winona
#
# In this lab, we will download and combine a decades worth of weather data from the NOAA, focusing on weather stations within 500 miles of Winona.
#
# Here is the outline of the basic process.
#
# 1. Install and investigate useful packages.
# 2. Find all weather stations in proximity to Winona.
# 3. Use a single station to prototype our tools.
# 4. Automate the process of downloading and uncompressing data from all stations of interest.
# 5. Output the results to a CSV file.

# %% [markdown]
# ## Problem 1 - Install and investigate useful tools.
#
# First, you should install and investigate the following tools.
#
# 1. **`wget`** is a tool for programmically downloading data files from the web on the command line.  There is a Python wrapper to this tool that you can install with `pip` as shown below.
# 2. **`geopy`** is a package that, among other things, implements a function for computing distances between two lat-long pairs. Again, install this package with `pip` as shown below.
# 3. **`gzip`** is part of the standard Python library and

# %%
# %pip install wget
# Out:
# Requirement already satisfied: wget in c:\users\at3571rj\appdata\local\anaconda3\envs\polars\lib\site-packages (3.2)Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install geopy
# Out:
# Requirement already satisfied: geopy in c:\users\at3571rj\appdata\local\anaconda3\envs\polars\lib\site-packages (2.4.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: geographiclib<3,>=1.52 in c:\users\at3571rj\appdata\local\anaconda3\envs\polars\lib\site-packages (from geopy) (2.0)

# %% [markdown]
# #### Task 1.1 - Investigate using `wget` to download a file.
#
# Read the help/documentation on `wget` to figure out how to download the following data file [Some random data file from STAT 210] into the `./data` sub-folder.
#
# [https://github.com/yardsale8/STAT_210/raw/refs/heads/main/data/sars1.csv](https://github.com/yardsale8/STAT_210/raw/refs/heads/main/data/sars1.csv)

# %%
import wget
import os

# %%
import os
import wget
import datetime

# Define URL and directory
url = "https://github.com/yardsale8/STAT_210/raw/refs/heads/main/data/sars1.csv"
download_dir = "./data"

# Ensure directory exists
os.makedirs(download_dir, exist_ok=True)

# Create a unique filename with timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
unique_filename = f"sars1_{timestamp}.csv"
output_path = os.path.join(download_dir, unique_filename)

try:
    # Download file
    filename = wget.download(url, out=output_path)
    print(f"\nFile successfully downloaded to: {filename}")
except Exception as e:
    print(f"\nFailed to download file: {e}")
# Out:
# 100% [................................................................................] 1519 / 1519
# File successfully downloaded to: ./data\sars1_20250213_081906.csv

# %% [markdown]
# #### Task 1.2 - Investigate using `geopy.distance.distance` to compute a distance in miles.
#
# 1. Import the `distance` function from the `geopy.distance` submodule.
# 2. Use Wikipedia to find the lat-long coordinates of Winona and Rochester MN.
# 3. Use `distance` to compute the distance between Winona and Rochester.
# 4. Use some other source (e.g., Google Maps) to check the answer.

# %%
import geopy

# %%
# Your code here
from geopy.distance import distance

# %%
winona = (44.050556, -91.668333)
rochester = (44.023333, -92.461389)

print(distance.distance(winona, rochester).miles)
# Out:
# 39.54418575388878

# %% [markdown]
# #### Task 1.3 - Investigate `gzip`
#
# The yearly NOAA data is compressed as `.gz` files, which need to be uncompressed using `gzip`.  Explore the `gzip` module by
#
# 1. Exploring the documentation/help for the `gzip` module,
# 2. Using `wget` to download the following link into the `./data` folder, and
# 3. Using `gzip` to uncompress this file.
# 4. Inspect the data in your list, which should be of type `byte`.  Use a comprehension with the expression `l.decode('utf-8')` to convert this to a list of strings.
# 5. Write the uncompressed lines to an output file using `with open(path, 'w') as out` and the `writelines` method of `out`.
#
# **Link.** [https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_year/1750.csv.gz](https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_year/1750.csv.gz)

# %%
import gzip
help(gzip)
# Out:
# Help on module gzip:
#
# NAME
#     gzip - Functions that read and write gzipped files.
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/gzip.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     The user of the file doesn't have to worry about the compression,
#     but random access is not allowed.
#
# CLASSES
#     _compression.BaseStream(io.BufferedIOBase)
#         GzipFile
#     builtins.OSError(builtins.Exception)
#         BadGzipFile
#
#     class BadGzipFile(builtins.OSError)
#      |  Exception raised in some cases for invalid gzip files.
#      |
#      |  Method resolution order:
#      |      BadGzipFile
#      |      builtins.OSError
#      |      builtins.Exception
#      |      builtins.BaseException
#      |      builtins.object
#      |
#      |  Data descriptors defined here:
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.OSError:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  __reduce__(...)
#      |      Helper for pickle.
#      |
#      |  __str__(self, /)
#      |      Return str(self).
#      |
#      |  ----------------------------------------------------------------------
#      |  Static methods inherited from builtins.OSError:
#      |
#      |  __new__(*args, **kwargs) class method of builtins.OSError
#      |      Create and return a new object.  See help(type) for accurate signature.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.OSError:
#      |
#      |  characters_written
#      |
#      |  errno
#      |      POSIX exception code
#      |
#      |  filename
#      |      exception filename
#      |
#      |  filename2
#      |      second exception filename
#      |
#      |  strerror
#      |      exception strerror
#      |
#      |  winerror
#      |      Win32 exception code
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from builtins.BaseException:
#      |
#      |  __getattribute__(self, name, /)
#      |      Return getattr(self, name).
#      |
#      |  __repr__(self, /)
#      |      Return repr(self).
#      |
#      |  __setstate__(...)
#      |
#      |  add_note(...)
#      |      Exception.add_note(note) --
#      |      add a note to the exception
#      |
#      |  with_traceback(...)
#      |      Exception.with_traceback(tb) --
#      |      set self.__traceback__ to tb and return self.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from builtins.BaseException:
#      |
#      |  __cause__
#      |      exception cause
#      |
#      |  __context__
#      |      exception context
#      |
#      |  __dict__
#      |
#      |  __suppress_context__
#      |
#      |  __traceback__
#      |
#      |  args
#
#     class GzipFile(_compression.BaseStream)
#      |  GzipFile(filename=None, mode=None, compresslevel=9, fileobj=None, mtime=None)
#      |
#      |  The GzipFile class simulates most of the methods of a file object with
#      |  the exception of the truncate() method.
#      |
#      |  This class only supports opening files in binary mode. If you need to open a
#      |  compressed file in text mode, use the gzip.open() function.
#      |
#      |  Method resolution order:
#      |      GzipFile
#      |      _compression.BaseStream
#      |      io.BufferedIOBase
#      |      _io._BufferedIOBase
#      |      io.IOBase
#      |      _io._IOBase
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, filename=None, mode=None, compresslevel=9, fileobj=None, mtime=None)
#      |      Constructor for the GzipFile class.
#      |
#      |      At least one of fileobj and filename must be given a
#      |      non-trivial value.
#      |
#      |      The new class instance is based on fileobj, which can be a regular
#      |      file, an io.BytesIO object, or any other object which simulates a file.
#      |      It defaults to None, in which case filename is opened to provide
#      |      a file object.
#      |
#      |      When fileobj is not None, the filename argument is only used to be
#      |      included in the gzip file header, which may include the original
#      |      filename of the uncompressed file.  It defaults to the filename of
#      |      fileobj, if discernible; otherwise, it defaults to the empty string,
#      |      and in this case the original filename is not included in the header.
#      |
#      |      The mode argument can be any of 'r', 'rb', 'a', 'ab', 'w', 'wb', 'x', or
#      |      'xb' depending on whether the file will be read or written.  The default
#      |      is the mode of fileobj if discernible; otherwise, the default is 'rb'.
#      |      A mode of 'r' is equivalent to one of 'rb', and similarly for 'w' and
#      |      'wb', 'a' and 'ab', and 'x' and 'xb'.
#      |
#      |      The compresslevel argument is an integer from 0 to 9 controlling the
#      |      level of compression; 1 is fastest and produces the least compression,
#      |      and 9 is slowest and produces the most compression. 0 is no compression
#      |      at all. The default is 9.
#      |
#      |      The mtime argument is an optional numeric timestamp to be written
#      |      to the last modification time field in the stream when compressing.
#      |      If omitted or None, the current time is used.
#      |
#      |  __repr__(self)
#      |      Return repr(self).
#      |
#      |  close(self)
#      |      Flush and close the IO object.
#      |
#      |      This method has no effect if the file is already closed.
#      |
#      |  fileno(self)
#      |      Invoke the underlying file object's fileno() method.
#      |
#      |      This will raise AttributeError if the underlying file object
#      |      doesn't support fileno().
#      |
#      |  flush(self, zlib_mode=2)
#      |      Flush write buffers, if applicable.
#      |
#      |      This is not implemented for read-only and non-blocking streams.
#      |
#      |  peek(self, n)
#      |
#      |  read(self, size=-1)
#      |      Read and return up to n bytes.
#      |
#      |      If the size argument is omitted, None, or negative, read and
#      |      return all data until EOF.
#      |
#      |      If the size argument is positive, and the underlying raw stream is
#      |      not 'interactive', multiple raw reads may be issued to satisfy
#      |      the byte count (unless EOF is reached first).
#      |      However, for interactive raw streams (as well as sockets and pipes),
#      |      at most one raw read will be issued, and a short result does not
#      |      imply that EOF is imminent.
#      |
#      |      Return an empty bytes object on EOF.
#      |
#      |      Return None if the underlying raw stream was open in non-blocking
#      |      mode and no data is available at the moment.
#      |
#      |  read1(self, size=-1)
#      |      Implements BufferedIOBase.read1()
#      |
#      |      Reads up to a buffer's worth of data if size is negative.
#      |
#      |  readable(self)
#      |      Return whether object was opened for reading.
#      |
#      |      If False, read() will raise OSError.
#      |
#      |  readline(self, size=-1)
#      |      Read and return a line from the stream.
#      |
#      |      If size is specified, at most size bytes will be read.
#      |
#      |      The line terminator is always b'\n' for binary files; for text
#      |      files, the newlines argument to open can be used to select the line
#      |      terminator(s) recognized.
#      |
#      |  rewind(self)
#      |      Return the uncompressed stream file position indicator to the
#      |      beginning of the file
#      |
#      |  seek(self, offset, whence=0)
#      |      Change the stream position to the given byte offset.
#      |
#      |        offset
#      |          The stream position, relative to 'whence'.
#      |        whence
#      |          The relative position to seek from.
#      |
#      |      The offset is interpreted relative to the position indicated by whence.
#      |      Values for whence are:
#      |
#      |      * os.SEEK_SET or 0 -- start of stream (the default); offset should be zero or positive
#      |      * os.SEEK_CUR or 1 -- current stream position; offset may be negative
#      |      * os.SEEK_END or 2 -- end of stream; offset is usually negative
#      |
#      |      Return the new absolute position.
#      |
#      |  seekable(self)
#      |      Return whether object supports random access.
#      |
#      |      If False, seek(), tell() and truncate() will raise OSError.
#      |      This method may need to do a test seek().
#      |
#      |  tell(self)
#      |      Return current stream position.
#      |
#      |  writable(self)
#      |      Return whether object was opened for writing.
#      |
#      |      If False, write() will raise OSError.
#      |
#      |  write(self, data)
#      |      Write buffer b to the IO stream.
#      |
#      |      Return the number of bytes written, which is always
#      |      the length of b in bytes.
#      |
#      |      Raise BlockingIOError if the buffer is full and the
#      |      underlying raw stream cannot accept more data at the moment.
#      |
#      |  ----------------------------------------------------------------------
#      |  Readonly properties defined here:
#      |
#      |  closed
#      |
#      |  mtime
#      |      Last modification time read from stream, or None
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  __abstractmethods__ = frozenset()
#      |
#      |  myfileobj = None
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from _io._BufferedIOBase:
#      |
#      |  detach(self, /)
#      |      Disconnect this buffer from its underlying raw stream and return it.
#      |
#      |      After the raw stream has been detached, the buffer is in an unusable
#      |      state.
#      |
#      |  readinto(self, buffer, /)
#      |
#      |  readinto1(self, buffer, /)
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from _io._IOBase:
#      |
#      |  __del__(...)
#      |
#      |  __enter__(...)
#      |
#      |  __exit__(...)
#      |
#      |  __iter__(self, /)
#      |      Implement iter(self).
#      |
#      |  __next__(self, /)
#      |      Implement next(self).
#      |
#      |  isatty(self, /)
#      |      Return whether this is an 'interactive' stream.
#      |
#      |      Return False if it can't be determined.
#      |
#      |  readlines(self, hint=-1, /)
#      |      Return a list of lines from the stream.
#      |
#      |      hint can be specified to control the number of lines read: no more
#      |      lines will be read if the total size (in bytes/characters) of all
#      |      lines so far exceeds hint.
#      |
#      |  truncate(self, size=None, /)
#      |      Truncate file to size bytes.
#      |
#      |      File pointer is left unchanged. Size defaults to the current IO position
#      |      as reported by tell(). Return the new size.
#      |
#      |  writelines(self, lines, /)
#      |      Write a list of lines to stream.
#      |
#      |      Line separators are not added, so it is usual for each of the
#      |      lines provided to have a line separator at the end.
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors inherited from _io._IOBase:
#      |
#      |  __dict__
#
# FUNCTIONS
#     compress(data, compresslevel=9, *, mtime=None)
#         Compress data in one shot and return the compressed string.
#
#         compresslevel sets the compression level in range of 0-9.
#         mtime can be used to set the modification time. The modification time is
#         set to the current time by default.
#
#     decompress(data)
#         Decompress a gzip compressed string in one shot.
#         Return the decompressed string.
#
#     open(filename, mode='rb', compresslevel=9, encoding=None, errors=None, newline=None)
#         Open a gzip-compressed file in binary or text mode.
#
#         The filename argument can be an actual filename (a str or bytes object), or
#         an existing file object to read from or write to.
#
#         The mode argument can be "r", "rb", "w", "wb", "x", "xb", "a" or "ab" for
#         binary mode, or "rt", "wt", "xt" or "at" for text mode. The default mode is
#         "rb", and the default compresslevel is 9.
#
#         For binary mode, this function is equivalent to the GzipFile constructor:
#         GzipFile(filename, mode, compresslevel). In this case, the encoding, errors
#         and newline arguments must not be provided.
#
#         For text mode, a GzipFile object is created, and wrapped in an
#         io.TextIOWrapper instance with the specified encoding, error handling
#         behavior, and line ending(s).
#
# DATA
#     __all__ = ['BadGzipFile', 'GzipFile', 'open', 'compress', 'decompress'...
#
# FILE
#     c:\users\at3571rj\appdata\local\anaconda3\envs\polars\lib\gzip.py

# %%
# Your code hereimport gzip

# Download the file into the ./data folder
url = "https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_year/1750.csv.gz"
output_path = "./data/1750.csv.gz"  # My file path

filename = wget.download(url, out=output_path)

print(f"File downloaded to: {filename}")
# Out:
# 100% [..........................................................................] 1385743 / 1385743File downloaded to: ./data/1750.csv.gz

# %%
# Define input and output file paths
file_to_uncompress = './data/1750.csv.gz'
output_file = './data/1750_uncompressed.csv'

# Step 1: Read the compressed file as bytes
# .gz file is a binary file. 
# So, you have to use 'rb' instead of 'r'
with open(file_to_uncompress, 'rb') as f: 
    compressed_data = f.read()  # Read the entire file in binary mode

# Step 2: Decompress the data
decompressed_data = gzip.decompress(compressed_data)  # Returns bytes

# Step 3: Convert bytes to string and split into lines
string_lines = decompressed_data.decode('utf-8').splitlines(keepends=True)

# Step 4: Write the uncompressed lines to an output file
with open(output_file, 'w') as out:
    out.writelines(string_lines)

print(f"Uncompressed file saved as: {output_file}")
# Out:
# Uncompressed file saved as: ./data/1750_uncompressed.csv

# %% [markdown]
# ## Problem 2 - Find all stations within 500 miles of Winona, MN.
#
# The file linked below contains information about all stations tracked by NOAA.
#
# *Main folder:* https://www.ncei.noaa.gov/pub/data/ghcn/daily/
#
# *Station txt file:* https://www.ncei.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt
#
# *Note.* While it would be easier to use the CSV version of the station file, you should use the TXT version here (for practice).
#
# **Your tasks** Our goal is to get a list of stations that are within 500 miles of Winona.  Do this by
#
# 1. Using `wget` to download the stations information into the `./data` folder.
# 2. Use `with` to read the lines of this file.
# 3. At this point, the lines are strings in a fixed-width format separated by whitespace.  Use a list comprehension with the string split method to split the raw lines (strings) into a list of entries.
# 4. There are three entries of interest, the station ID and the lat-long coordinates of the station.  Inspect the file to determine the index for these three entries.
# 5. We want to transform the lines (currently a list of strings) into a record, which is a `dict` with good names for the entries as keys and the values representing the data in an appropriate type (string for station ID, `float` for the lat-long).  Use a comprehension to create a list of records as described.
# 6. Use another comprehension to apply a filter to the stations, keeping only those within 500 miles of Winona.

# %%
url = "https://www.ncei.noaa.gov/pub/data/ghcn/daily/ghcnd-stations.txt"
output_path = "./data/ghcnd-stations.txt"  # My file path

filename = wget.download(url, out=output_path)

print(f"File downloaded to: {filename}")
# Out:
# 100% [........................................................................] 11150330 / 11150330File downloaded to: ./data/ghcnd-stations.txt

# %%
with open('./data/ghcnd-stations.txt') as f:
    lines = f.readlines()
lines[:5]
# Out:
# ['ACW00011604  17.1167  -61.7833   10.1    ST JOHNS COOLIDGE FLD                       \n',
#  'ACW00011647  17.1333  -61.7833   19.2    ST JOHNS                                    \n',
#  'AE000041196  25.3330   55.5170   34.0    SHARJAH INTER. AIRP            GSN     41196\n',
#  'AEM00041194  25.2550   55.3640   10.4    DUBAI INTL                             41194\n',
#  'AEM00041217  24.4330   54.6510   26.8    ABU DHABI INTL                         41217\n']

# %%
# By default, split() handles multiple consecutive whitespace characters as a single delimiter.
split_lines = [line.split() for line in lines]
split_lines[:3]
# Out:
# [['ACW00011604',
#   '17.1167',
#   '-61.7833',
#   '10.1',
#   'ST',
#   'JOHNS',
#   'COOLIDGE',
#   'FLD'],
#  ['ACW00011647', '17.1333', '-61.7833', '19.2', 'ST', 'JOHNS'],
#  ['AE000041196',
#   '25.3330',
#   '55.5170',
#   '34.0',
#   'SHARJAH',
#   'INTER.',
#   'AIRP',
#   'GSN',
#   '41196']]

# %%
# List comprehension to create records (dicts) with keys: 'station_id', 'latitude', 'longitude'
stations = [
            {'station_id': line[0],       # Keep this as string
             'latitude': float(line[1]),  # Convert to float for latitude
             'longitude': float(line[2])  # Convert to float for longitude
            }
    for line in split_lines]

# Print the first 3 records
print(stations[:3])
# Out:
# [{'station_id': 'ACW00011604', 'latitude': 17.1167, 'longitude': -61.7833}, {'station_id': 'ACW00011647', 'latitude': 17.1333, 'longitude': -61.7833}, {'station_id': 'AE000041196', 'latitude': 25.333, 'longitude': 55.517}]

# %%
print(distance.distance(winona, rochester).miles)
# Out:
# 39.54418575388878

# %%
from geopy import distance

winona = (44.050556, -91.668333)

# Filter stations within 500 miles of Winona
nearby_stations = [
    station for station in stations
    if distance.geodesic(winona, (station['latitude'], station['longitude'])).miles <= 500
]

# Print filtered stations
print(nearby_stations[:3])
# Out:
# [{'station_id': 'CA005012710', 'latitude': 49.45, 'longitude': -98.6167}, {'station_id': 'CA005020036', 'latitude': 49.55, 'longitude': -98.2}, {'station_id': 'CA005020040', 'latitude': 49.1, 'longitude': -97.55}]

# %% [markdown]
# #### Problem 3 - Prototype downloading and uncompressing a station file.
#
# Before we download and uncompress all the stations of interest, let's practice on one station file.
#
#
# 1. Copy the url for some station and store is as a variable named `url`.
# 2. Write `lambda` functions that extract each of the following from the station `url`: compressed file name, compressed file path (e.g., `./data/...`), and uncompressed file path (e.g., `./data/...`).
# 3. Write a `lambda` function that extracts
# 4. Use `wget` to download this stations data.
# 5. Use `gzip` to uncompress the data.
# 6. Write the data to out output file.
#
# Your code should have the following shape:
#
# ```{Python}
# wget.download(...)
# with gzip.open(...) as f:
#     with open(..., 'w') as out:
#         f.readlines()
#         out.writelines(f)
# ```
#
# You should be using your helper functions to, in part, fill in the `...`

# %%
# Review lambda function 
add_lambda = lambda x, y: x + y

# Usage
print(add_lambda(3, 5))  # Output: 8
# Out:
# 8

# %%
# ACW00011604.csv.gz
url = 'https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/ACW00011604.csv.gz'

# %%
# lambda to extract compressed file name

extract_comp_file_name = lambda url: url.split('/')[-1]
print(extract_comp_file_name(url))
# Out:
# ACW00011604.csv.gz

# %%
# lambda to extract compressed file path

extract_comp_file_path = lambda url: '.' + url.split('pub')[1]
print(extract_comp_file_path(url))
# Out:
# ./data/ghcn/daily/by_station/ACW00011604.csv.gz

# %%
# lambda to extract uncompressed file path

extract_uncomp_file_path = lambda url: '.' + url.split('pub')[1].replace('.gz', '')
print(extract_uncomp_file_path(url))
# Out:
# ./data/ghcn/daily/by_station/ACW00011604.csv

# %%
# ACW00011604.csv.gz
url = 'https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/ACW00011604.csv.gz'

# Download the compressed file
compressed_file_path = extract_comp_file_path(url)
uncompressed_file_path = extract_uncomp_file_path(url)

wget.download(url, compressed_file_path)

# Uncompress the file and write to an output file
with gzip.open(compressed_file_path, 'rt') as f:
    with open(uncompressed_file_path, 'w') as out:
        out.writelines(f.readlines())

print(f"Uncompressed file downloaded to: {uncompressed_file_path}")
# Out:
# 100% [................................................................................] 3943 / 3943Uncompressed file downloaded to: ./data/ghcn/daily/by_station\ACW00011604.csv

# %% [markdown]
# ## Problem 4 - Build the station URLs and download the files.
#
# **Tasks.** Now you need to build urls for all stations of interest by
#
# 1. Use a comprehension to extract the stations of interest into a list.
# 2. Investigating the structure of the files stored in the `by_station` folder (see main folder link above).
# 3. Use a comprehension and an `f` string to build a list of URLS for all stations of interest.
# 4. Use `wget` to download the data for the stations of interest into the data folder.
# 5. Use `gzip` to uncompress the files.
# 6. Convert the `bytes` to `str` of format `utf-8`.
# 7. Use the append mode `"a"` of `open` with `writelines` to append the data in each file to your output file.
#
# While we usually avoid using a `for` loop, we make an exception for code for lengthy IO.  To accomplish steps 4 & 5, use a `for` loop with the following shape.
#
# ```{Python}
# for url in station_urls:
#     wget.download(...)
#     with gzip.open(...) as f:
#         with open(..., 'a') as out:
#             f.readlines()
#             ... # Convert lines to strings here
#             out.writelines(f)
#     print(f"Downloaded and extracted the data for {url}")
# ```
#
# Note that the code inside the loop should resemble the code from the previous step.

# %%
# Your code here.

# %%
fake_station = "A123456789"
make_fake_url = lambda s: f"https://my_fake_website.cool/{s}"

make_fake_url(fake_station)
# Out:
# 'https://my_fake_website.cool/A123456789'

# %%
my_fake_stations =[f'A{i}' for i in range(10)]

(my_fake_urls := [make_fake_url(s) for s in my_fake_stations])
# Out:
# ['https://my_fake_website.cool/A0',
#  'https://my_fake_website.cool/A1',
#  'https://my_fake_website.cool/A2',
#  'https://my_fake_website.cool/A3',
#  'https://my_fake_website.cool/A4',
#  'https://my_fake_website.cool/A5',
#  'https://my_fake_website.cool/A6',
#  'https://my_fake_website.cool/A7',
#  'https://my_fake_website.cool/A8',
#  'https://my_fake_website.cool/A9']

# %%
# Your code here
nearby_station_ids = [station['station_id'] for station in nearby_stations]
print(nearby_station_ids[:3])
# Out:
# ['CA005012710', 'CA005020036', 'CA005020040']

# %%
station = "CA005012710"
make_station_url = lambda s: f"https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/{s}.csv.gz"

make_station_url(station)
# Out:
# 'https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005012710.csv.gz'

# %%
station_urls = [make_station_url(s) for s in nearby_station_ids]
station_urls[:3]
# Out:
# ['https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005012710.csv.gz',
#  'https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020036.csv.gz',
#  'https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020040.csv.gz']

# %%
extract_comp_file_name = lambda url: url.split('/')[-1]
print(f'Compressed File Name: {extract_comp_file_name(url)}')

# lambda to extract compressed file path
extract_comp_file_path = lambda url: '.' + url.split('pub')[1]
print(f'Compressed File Path: {extract_comp_file_path(url)}')

# lambda to extract uncompressed file path
extract_uncomp_file_path = lambda url: '.' + url.split('pub')[1].replace('.gz', '')
print(f'Uncompressed File Path: {extract_uncomp_file_path(url)}')
# Out:
# Compressed File Name: ACW00011604.csv.gz
# Compressed File Path: ./data/ghcn/daily/by_station/ACW00011604.csv.gz
# Uncompressed File Path: ./data/ghcn/daily/by_station/ACW00011604.csv

# %%
for url in station_urls:
    wget.download(url, extract_comp_file_path(url))

    with gzip.open(extract_comp_file_path(url), 'rt', encoding='utf-8') as f:  # Ensure UTF-8 decoding
        with open(extract_uncomp_file_path(url), 'w', encoding='utf-8') as out:  # Use 'w' to overwrite
            lines = f.readlines()  
            lines = [line.strip() + '\n' for line in lines]  # Strip unwanted spaces & ensure newline
            out.writelines(lines)  # Write cleaned lines to file

    print(f"Downloaded and extracted the data for {url}")
# Out:
# 100% [............................................................................] 157920 / 157920Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005012710.csv.gz
# 100% [............................................................................] 118189 / 118189Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020036.csv.gz
# 100% [............................................................................] 304838 / 304838Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020040.csv.gz
# 100% [..............................................................................] 40754 / 40754Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020050.csv.gz
# 100% [..............................................................................] 11861 / 11861Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020054.csv.gz
# 100% [................................................................................] 3898 / 3898Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020069.csv.gz
# 100% [..............................................................................] 13610 / 13610Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020224.csv.gz
# 100% [............................................................................] 208806 / 208806Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020551.csv.gz
# 100% [..............................................................................] 58995 / 58995Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020553.csv.gz
# 100% [..............................................................................] 28641 / 28641Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020625.csv.gz
# 100% [................................................................................] 7438 / 7438Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020648.csv.gz
# 100% [................................................................................] 3914 / 3914Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020670.csv.gz
# 100% [................................................................................] 4042 / 4042Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020672.csv.gz
# 100% [............................................................................] 237817 / 237817Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020720.csv.gz
# 100% [............................................................................] 159911 / 159911Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020725.csv.gz
# 100% [..............................................................................] 43092 / 43092Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020768.csv.gz
# 100% [................................................................................] 5636 / 5636Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020770.csv.gz
# 100% [..............................................................................] 14340 / 14340Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020807.csv.gz
# 100% [............................................................................] 129634 / 129634Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020810.csv.gz
# 100% [............................................................................] 136311 / 136311Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020870.csv.gz
# 100% [............................................................................] 399162 / 399162Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020880.csv.gz
# 100% [............................................................................] 113968 / 113968Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020881.csv.gz
# 100% [..............................................................................] 68210 / 68210Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020882.csv.gz
# 100% [..............................................................................] 85474 / 85474Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020913.csv.gz
# 100% [................................................................................] 4045 / 4045Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020990.csv.gz
# 100% [..............................................................................] 14243 / 14243Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005020N53.csv.gz
# 100% [............................................................................] 220559 / 220559Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021054.csv.gz
# 100% [..............................................................................] 21916 / 21916Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021058.csv.gz
# 100% [............................................................................] 319232 / 319232Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021160.csv.gz
# 100% [............................................................................] 100433 / 100433Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021205.csv.gz
# 100% [............................................................................] 315587 / 315587Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021220.csv.gz
# 100% [............................................................................] 106292 / 106292Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021225.csv.gz
# 100% [................................................................................] 7579 / 7579Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021285.csv.gz
# 100% [..............................................................................] 10921 / 10921Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021306.csv.gz
# 100% [..............................................................................] 19421 / 19421Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021395.csv.gz
# 100% [..............................................................................] 50811 / 50811Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021529.csv.gz
# 100% [..............................................................................] 16366 / 16366Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021565.csv.gz
# 100% [..............................................................................] 72193 / 72193Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021687.csv.gz
# 100% [..............................................................................] 59535 / 59535Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021688.csv.gz
# 100% [..............................................................................] 29667 / 29667Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021689.csv.gz
# 100% [................................................................................] 1008 / 1008Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021690.csv.gz
# 100% [..............................................................................] 38278 / 38278Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021692.csv.gz
# 100% [................................................................................] 6702 / 6702Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021732.csv.gz
# 100% [..............................................................................] 25512 / 25512Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021735.csv.gz
# 100% [............................................................................] 125080 / 125080Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021736.csv.gz
# 100% [............................................................................] 231857 / 231857Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021737.csv.gz
# 100% [................................................................................] 4089 / 4089Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021812.csv.gz
# 100% [............................................................................] 336451 / 336451Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021840.csv.gz
# 100% [............................................................................] 484982 / 484982Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021848.csv.gz
# 100% [............................................................................] 176307 / 176307Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021849.csv.gz
# 100% [..............................................................................] 44670 / 44670Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021854.csv.gz
# 100% [............................................................................] 335628 / 335628Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021920.csv.gz
# 100% [................................................................................] 5223 / 5223Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021960.csv.gz
# 100% [............................................................................] 119932 / 119932Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021965.csv.gz
# 100% [............................................................................] 210731 / 210731Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021975.csv.gz
# 100% [..............................................................................] 81292 / 81292Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021977.csv.gz
# 100% [..............................................................................] 60040 / 60040Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005021992.csv.gz
# 100% [............................................................................] 161339 / 161339Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022043.csv.gz
# 100% [............................................................................] 329477 / 329477Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022051.csv.gz
# 100% [..............................................................................] 16836 / 16836Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022056.csv.gz
# 100% [..............................................................................] 24074 / 24074Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022068.csv.gz
# 100% [..............................................................................] 81760 / 81760Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022070.csv.gz
# 100% [..............................................................................] 63586 / 63586Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022100.csv.gz
# 100% [..............................................................................] 25104 / 25104Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022119.csv.gz
# 100% [..............................................................................] 91552 / 91552Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022120.csv.gz
# 100% [............................................................................] 386962 / 386962Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022125.csv.gz
# 100% [............................................................................] 110750 / 110750Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022129.csv.gz
# 100% [................................................................................] 6445 / 6445Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022170.csv.gz
# 100% [............................................................................] 186359 / 186359Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022171.csv.gz
# 100% [............................................................................] 227430 / 227430Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022245.csv.gz
# 100% [..............................................................................] 24557 / 24557Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022420.csv.gz
# 100% [............................................................................] 148397 / 148397Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022480.csv.gz
# 100% [................................................................................] 2597 / 2597Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022488.csv.gz
# 100% [..............................................................................] 25398 / 25398Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022490.csv.gz
# 100% [..............................................................................] 11281 / 11281Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022491.csv.gz
# 100% [..............................................................................] 29291 / 29291Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022492.csv.gz
# 100% [..............................................................................] 10552 / 10552Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022504.csv.gz
# 100% [..............................................................................] 68806 / 68806Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022547.csv.gz
# 100% [..............................................................................] 23834 / 23834Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022549.csv.gz
# 100% [............................................................................] 104947 / 104947Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502254Q.csv.gz
# 100% [............................................................................] 140371 / 140371Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022550.csv.gz
# 100% [..............................................................................] 33392 / 33392Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022553.csv.gz
# 100% [................................................................................] 5430 / 5430Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022567.csv.gz
# 100% [............................................................................] 121604 / 121604Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022575.csv.gz
# 100% [..............................................................................] 57286 / 57286Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA0050225DP.csv.gz
# 100% [..............................................................................] 47200 / 47200Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022601.csv.gz
# 100% [..............................................................................] 32628 / 32628Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022603.csv.gz
# 100% [..............................................................................] 65256 / 65256Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022606.csv.gz
# 100% [............................................................................] 106093 / 106093Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022623.csv.gz
# 100% [............................................................................] 235637 / 235637Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022630.csv.gz
# 100% [............................................................................] 133810 / 133810Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022703.csv.gz
# 100% [..............................................................................] 99051 / 99051Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022740.csv.gz
# 100% [............................................................................] 206182 / 206182Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022759.csv.gz
# 100% [............................................................................] 453939 / 453939Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022760.csv.gz
# 100% [............................................................................] 230759 / 230759Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022770.csv.gz
# 100% [............................................................................] 278097 / 278097Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022780.csv.gz
# 100% [............................................................................] 168688 / 168688Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022788.csv.gz
# 100% [............................................................................] 195442 / 195442Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022790.csv.gz
# 100% [............................................................................] 318430 / 318430Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022791.csv.gz
# 100% [..............................................................................] 33961 / 33961Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022797.csv.gz
# 100% [..............................................................................] 47576 / 47576Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022798.csv.gz
# 100% [................................................................................] 3113 / 3113Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022928.csv.gz
# 100% [................................................................................] 3299 / 3299Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022EDQ.csv.gz
# 100% [..............................................................................] 23366 / 23366Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005022G04.csv.gz
# 100% [..............................................................................] 57027 / 57027Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023000.csv.gz
# 100% [..............................................................................] 17414 / 17414Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023001.csv.gz
# 100% [..............................................................................] 41452 / 41452Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023149.csv.gz
# 100% [..................................................................................] 708 / 708Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023170.csv.gz
# 100% [................................................................................] 3721 / 3721Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023174.csv.gz
# 100% [................................................................................] 3691 / 3691Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023178.csv.gz
# 100% [..................................................................................] 937 / 937Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023180.csv.gz
# 100% [..............................................................................] 22889 / 22889Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023190.csv.gz
# 100% [................................................................................] 4135 / 4135Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA0050231R0.csv.gz
# 100% [................................................................................] 4313 / 4313Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023200.csv.gz
# 100% [................................................................................] 9328 / 9328Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023210.csv.gz
# 100% [................................................................................] 2756 / 2756Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023220.csv.gz
# 100% [............................................................................] 462279 / 462279Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023222.csv.gz
# 100% [................................................................................] 4921 / 4921Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023223.csv.gz
# 100% [..............................................................................] 19453 / 19453Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023224.csv.gz
# 100% [..............................................................................] 40806 / 40806Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023225.csv.gz
# 100% [..............................................................................] 24929 / 24929Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023226.csv.gz
# 100% [................................................................................] 6450 / 6450Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023230.csv.gz
# 100% [..............................................................................] 43897 / 43897Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023233.csv.gz
# 100% [................................................................................] 2352 / 2352Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023240.csv.gz
# 100% [............................................................................] 366656 / 366656Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023243.csv.gz
# 100% [..............................................................................] 18932 / 18932Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023250.csv.gz
# 100% [................................................................................] 2894 / 2894Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023260.csv.gz
# 100% [............................................................................] 334095 / 334095Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023261.csv.gz
# 100% [............................................................................] 161118 / 161118Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023262.csv.gz
# 100% [................................................................................] 2259 / 2259Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023263.csv.gz
# 100% [..............................................................................] 51520 / 51520Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023265.csv.gz
# 100% [..............................................................................] 41359 / 41359Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023270.csv.gz
# 100% [................................................................................] 3707 / 3707Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023274.csv.gz
# 100% [................................................................................] 1125 / 1125Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023280.csv.gz
# 100% [................................................................................] 1959 / 1959Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023281.csv.gz
# 100% [................................................................................] 8809 / 8809Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023282.csv.gz
# 100% [................................................................................] 7872 / 7872Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023283.csv.gz
# 100% [................................................................................] 7656 / 7656Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023284.csv.gz
# 100% [................................................................................] 1422 / 1422Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023295.csv.gz
# 100% [..............................................................................] 13401 / 13401Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA0050232KJ.csv.gz
# 100% [............................................................................] 108717 / 108717Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005023370.csv.gz
# 100% [................................................................................] 1561 / 1561Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502C2JM.csv.gz
# 100% [................................................................................] 3704 / 3704Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502CKBD.csv.gz
# 100% [............................................................................] 195419 / 195419Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502I001.csv.gz
# 100% [..............................................................................] 18937 / 18937Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502I002.csv.gz
# 100% [................................................................................] 2623 / 2623Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502LA48.csv.gz
# 100% [..............................................................................] 30665 / 30665Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502M001.csv.gz
# 100% [............................................................................] 190195 / 190195Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00502S001.csv.gz
# 100% [............................................................................] 120190 / 120190Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030155.csv.gz
# 100% [............................................................................] 264604 / 264604Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030160.csv.gz
# 100% [................................................................................] 3632 / 3632Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030334.csv.gz
# 100% [..............................................................................] 30209 / 30209Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030335.csv.gz
# 100% [................................................................................] 3718 / 3718Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030523.csv.gz
# 100% [..............................................................................] 45767 / 45767Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030869.csv.gz
# 100% [............................................................................] 144642 / 144642Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005030912.csv.gz
# 100% [............................................................................] 421982 / 421982Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005031200.csv.gz
# 100% [............................................................................] 160480 / 160480Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005031201.csv.gz
# 100% [............................................................................] 650769 / 650769Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005031320.csv.gz
# 100% [................................................................................] 9270 / 9270Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005031511.csv.gz
# 100% [..............................................................................] 26484 / 26484Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005031512.csv.gz
# 100% [................................................................................] 3039 / 3039Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00503196F.csv.gz
# 100% [............................................................................] 197051 / 197051Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032160.csv.gz
# 100% [..............................................................................] 65929 / 65929Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032161.csv.gz
# 100% [............................................................................] 330668 / 330668Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032162.csv.gz
# 100% [............................................................................] 178965 / 178965Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032164.csv.gz
# 100% [................................................................................] 9311 / 9311Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032249.csv.gz
# 100% [............................................................................] 221416 / 221416Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032360.csv.gz
# 100% [..............................................................................] 54878 / 54878Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032495.csv.gz
# 100% [..............................................................................] 82509 / 82509Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032560.csv.gz
# 100% [............................................................................] 103036 / 103036Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032640.csv.gz
# 100% [................................................................................] 1238 / 1238Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032641.csv.gz
# 100% [..............................................................................] 77064 / 77064Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA005032764.csv.gz
# 100% [..............................................................................] 26581 / 26581Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00503B0MF.csv.gz
# 100% [............................................................................] 161698 / 161698Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00503B0NE.csv.gz
# 100% [............................................................................] 205532 / 205532Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00503B1ER.csv.gz
# 100% [............................................................................] 316734 / 316734Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006012198.csv.gz
# 100% [............................................................................] 169202 / 169202Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006012199.csv.gz
# 100% [............................................................................] 103518 / 103518Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006016890.csv.gz
# 100% [..............................................................................] 19547 / 19547Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006016970.csv.gz
# 100% [............................................................................] 434173 / 434173Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006016975.csv.gz
# 100% [................................................................................] 4611 / 4611Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006016979.csv.gz
# 100% [............................................................................] 157918 / 157918Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006020379.csv.gz
# 100% [............................................................................] 286946 / 286946Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006020381.csv.gz
# 100% [............................................................................] 112319 / 112319Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006020384.csv.gz
# 100% [............................................................................] 291290 / 291290Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006020559.csv.gz
# 100% [................................................................................] 3884 / 3884Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006020727.csv.gz
# 100% [............................................................................] 185089 / 185089Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006020LPQ.csv.gz
# 100% [..............................................................................] 33506 / 33506Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022010.csv.gz
# 100% [..............................................................................] 37124 / 37124Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022011.csv.gz
# 100% [............................................................................] 222670 / 222670Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022300.csv.gz
# 100% [..............................................................................] 23947 / 23947Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022301.csv.gz
# 100% [............................................................................] 124431 / 124431Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022474.csv.gz
# 100% [............................................................................] 480904 / 480904Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022475.csv.gz
# 100% [............................................................................] 207849 / 207849Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022476.csv.gz
# 100% [..............................................................................] 12891 / 12891Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022480.csv.gz
# 100% [..............................................................................] 50035 / 50035Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006022487.csv.gz
# 100% [..............................................................................] 66074 / 66074Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006024010.csv.gz
# 100% [............................................................................] 509141 / 509141Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006025203.csv.gz
# 100% [............................................................................] 126228 / 126228Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006025205.csv.gz
# 100% [..............................................................................] 52903 / 52903Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006025407.csv.gz
# 100% [..............................................................................] 98373 / 98373Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006026852.csv.gz
# 100% [................................................................................] 3439 / 3439Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006026853.csv.gz
# 100% [............................................................................] 143878 / 143878Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006027825.csv.gz
# 100% [..............................................................................] 94474 / 94474Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006028125.csv.gz
# 100% [................................................................................] 8059 / 8059Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006028127.csv.gz
# 100% [..............................................................................] 70910 / 70910Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006028128.csv.gz
# 100% [..............................................................................] 24317 / 24317Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00602B300.csv.gz
# 100% [..............................................................................] 11806 / 11806Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00602FQ5L.csv.gz
# 100% [............................................................................] 143315 / 143315Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA00602K300.csv.gz
# 100% [..............................................................................] 20656 / 20656Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006030488.csv.gz
# 100% [............................................................................] 452419 / 452419Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006032117.csv.gz
# 100% [............................................................................] 237534 / 237534Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006032119.csv.gz
# 100% [..............................................................................] 52093 / 52093Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006032120.csv.gz
# 100% [..............................................................................] 10683 / 10683Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006032122.csv.gz
# 100% [............................................................................] 100612 / 100612Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006032125.csv.gz
# 100% [................................................................................] 9818 / 9818Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006032192.csv.gz
# 100% [................................................................................] 6333 / 6333Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006033505.csv.gz
# 100% [............................................................................] 310561 / 310561Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006033690.csv.gz
# 100% [............................................................................] 116832 / 116832Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006033697.csv.gz
# 100% [..............................................................................] 73315 / 73315Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006033785.csv.gz
# 100% [............................................................................] 208142 / 208142Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006034070.csv.gz
# 100% [............................................................................] 120013 / 120013Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006034073.csv.gz
# 100% [............................................................................] 502951 / 502951Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006034075.csv.gz
# 100% [............................................................................] 112155 / 112155Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006034076.csv.gz
# 100% [..............................................................................] 85243 / 85243Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/CA006034077.csv.gz
# ...
# 100% [..............................................................................] 21852 / 21852Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl004.csv.gz
# 100% [................................................................................] 3320 / 3320Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl007.csv.gz
# 100% [..............................................................................] 26413 / 26413Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl008.csv.gz
# 100% [..............................................................................] 23565 / 23565Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl009.csv.gz
# 100% [..............................................................................] 23935 / 23935Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl010.csv.gz
# 100% [..............................................................................] 22896 / 22896Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl012.csv.gz
# 100% [................................................................................] 5458 / 5458Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl013.csv.gz
# 100% [..............................................................................] 10538 / 10538Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10harl014.csv.gz
# 100% [..............................................................................] 33765 / 33765Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt001.csv.gz
# 100% [..............................................................................] 15888 / 15888Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt002.csv.gz
# 100% [................................................................................] 4018 / 4018Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt003.csv.gz
# 100% [................................................................................] 5260 / 5260Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt004.csv.gz
# 100% [..................................................................................] 491 / 491Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt006.csv.gz
# 100% [..............................................................................] 14832 / 14832Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt007.csv.gz
# 100% [................................................................................] 6905 / 6905Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt008.csv.gz
# 100% [..............................................................................] 13939 / 13939Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt009.csv.gz
# 100% [..............................................................................] 16177 / 16177Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt010.csv.gz
# 100% [..............................................................................] 12220 / 12220Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt011.csv.gz
# 100% [................................................................................] 5519 / 5519Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt012.csv.gz
# 100% [................................................................................] 2907 / 2907Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt014.csv.gz
# 100% [................................................................................] 3024 / 3024Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt015.csv.gz
# 100% [................................................................................] 4644 / 4644Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt016.csv.gz
# 100% [................................................................................] 6012 / 6012Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt018.csv.gz
# 100% [..................................................................................] 811 / 811Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt019.csv.gz
# 100% [................................................................................] 2890 / 2890Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt022.csv.gz
# 100% [................................................................................] 2357 / 2357Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt023.csv.gz
# 100% [..............................................................................] 16713 / 16713Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt024.csv.gz
# 100% [................................................................................] 1608 / 1608Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10holt029.csv.gz
# 100% [..............................................................................] 26431 / 26431Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10hook001.csv.gz
# 100% [................................................................................] 2103 / 2103Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10hook004.csv.gz
# 100% [..............................................................................] 13914 / 13914Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10hook007.csv.gz
# 100% [................................................................................] 4075 / 4075Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10hook008.csv.gz
# 100% [..............................................................................] 30250 / 30250Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa001.csv.gz
# 100% [..............................................................................] 30923 / 30923Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa002.csv.gz
# 100% [..............................................................................] 19626 / 19626Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa003.csv.gz
# 100% [................................................................................] 6929 / 6929Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa004.csv.gz
# 100% [..............................................................................] 37064 / 37064Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa005.csv.gz
# 100% [..............................................................................] 18344 / 18344Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa007.csv.gz
# 100% [................................................................................] 7773 / 7773Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa008.csv.gz
# 100% [..............................................................................] 30704 / 30704Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa009.csv.gz
# 100% [................................................................................] 9860 / 9860Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10howa010.csv.gz
# 100% [..............................................................................] 36374 / 36374Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff001.csv.gz
# 100% [..............................................................................] 42111 / 42111Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff002.csv.gz
# 100% [..............................................................................] 40942 / 40942Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff003.csv.gz
# 100% [..............................................................................] 20130 / 20130Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff004.csv.gz
# 100% [................................................................................] 5023 / 5023Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff005.csv.gz
# 100% [..............................................................................] 44393 / 44393Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff006.csv.gz
# 100% [..............................................................................] 44256 / 44256Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff009.csv.gz
# 100% [..............................................................................] 10518 / 10518Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff011.csv.gz
# 100% [..............................................................................] 21477 / 21477Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff012.csv.gz
# 100% [................................................................................] 5150 / 5150Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff013.csv.gz
# 100% [..............................................................................] 36855 / 36855Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff014.csv.gz
# 100% [..............................................................................] 16138 / 16138Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff016.csv.gz
# 100% [................................................................................] 6177 / 6177Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff018.csv.gz
# 100% [..................................................................................] 699 / 699Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff019.csv.gz
# 100% [................................................................................] 7704 / 7704Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff020.csv.gz
# 100% [..............................................................................] 12829 / 12829Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff021.csv.gz
# 100% [................................................................................] 1355 / 1355Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff023.csv.gz
# 100% [................................................................................] 2925 / 2925Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10jeff025.csv.gz
# 100% [..............................................................................] 26008 / 26008Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john001.csv.gz
# 100% [..............................................................................] 26638 / 26638Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john002.csv.gz
# 100% [..............................................................................] 17805 / 17805Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john003.csv.gz
# 100% [..............................................................................] 20311 / 20311Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john004.csv.gz
# 100% [..............................................................................] 33056 / 33056Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john005.csv.gz
# 100% [................................................................................] 4743 / 4743Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john006.csv.gz
# 100% [................................................................................] 2190 / 2190Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john007.csv.gz
# 100% [..............................................................................] 24245 / 24245Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john008.csv.gz
# 100% [..............................................................................] 35727 / 35727Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john009.csv.gz
# 100% [..............................................................................] 15902 / 15902Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john010.csv.gz
# 100% [..............................................................................] 23761 / 23761Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john012.csv.gz
# 100% [................................................................................] 9866 / 9866Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john013.csv.gz
# 100% [..............................................................................] 13769 / 13769Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john014.csv.gz
# 100% [..............................................................................] 24755 / 24755Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john015.csv.gz
# 100% [................................................................................] 8437 / 8437Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john016.csv.gz
# 100% [..............................................................................] 29742 / 29742Downloaded and extracted the data for https://www.ncei.noaa.gov/pub/data/ghcn/daily/by_station/US10john017.csv.gz
